# %% [markdown]
# <a href="https://colab.research.google.com/github/Sriramya123456/codesoft/blob/main/Car_sales_predction(ANN%2C_Codesoft).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

print ('modules loaded')
# Out:
# modules loaded

# %% [markdown]
# Data Preprocessing

# %%
df = pd.read_csv('/content/sales_task4.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %% [markdown]
# Drop unneeded columns

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %% [markdown]
# Define X and y

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %% [markdown]
# Data Scaling

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %% [markdown]
# Data Splitting

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %% [markdown]
# Modal Structure

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Modal Training

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 0.2680 - mean_absolute_error: 0.4957 - val_loss: 0.2503 - val_mean_absolute_error: 0.4761
# Epoch 2/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2107 - mean_absolute_error: 0.4366 - val_loss: 0.2021 - val_mean_absolute_error: 0.4246
# Epoch 3/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1676 - mean_absolute_error: 0.3858 - val_loss: 0.1636 - val_mean_absolute_error: 0.3786
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1327 - mean_absolute_error: 0.3412 - val_loss: 0.1324 - val_mean_absolute_error: 0.3367
# Epoch 5/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.1050 - mean_absolute_error: 0.3001 - val_loss: 0.1045 - val_mean_absolute_error: 0.2947
# Epoch 6/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0806 - mean_absolute_error: 0.2595 - val_loss: 0.0799 - val_mean_absolute_error: 0.2519
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0597 - mean_absolute_error: 0.2191 - val_loss: 0.0586 - val_mean_absolute_error: 0.2097
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0420 - mean_absolute_error: 0.1789 - val_loss: 0.0414 - val_mean_absolute_error: 0.1711
# Epoch 9/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0284 - mean_absolute_error: 0.1424 - val_loss: 0.0286 - val_mean_absolute_error: 0.1396
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0189 - mean_absolute_error: 0.1130 - val_loss: 0.0199 - val_mean_absolute_error: 0.1140
# Epoch 11/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0132 - mean_absolute_error: 0.0915 - val_loss: 0.0146 - val_mean_absolute_error: 0.0971
# Epoch 12/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0101 - mean_absolute_error: 0.0791 - val_loss: 0.0120 - val_mean_absolute_error: 0.0887
# Epoch 13/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0090 - mean_absolute_error: 0.0735 - val_loss: 0.0109 - val_mean_absolute_error: 0.0853
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0086 - mean_absolute_error: 0.0720 - val_loss: 0.0104 - val_mean_absolute_error: 0.0841
# Epoch 15/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0085 - mean_absolute_error: 0.0713 - val_loss: 0.0102 - val_mean_absolute_error: 0.0835
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0085 - mean_absolute_error: 0.0710 - val_loss: 0.0102 - val_mean_absolute_error: 0.0833
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0084 - mean_absolute_error: 0.0707 - val_loss: 0.0101 - val_mean_absolute_error: 0.0831
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0083 - mean_absolute_error: 0.0705 - val_loss: 0.0101 - val_mean_absolute_error: 0.0828
# Epoch 19/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0083 - mean_absolute_error: 0.0702 - val_loss: 0.0100 - val_mean_absolute_error: 0.0826
# Epoch 20/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_absolute_error: 0.0699 - val_loss: 0.0100 - val_mean_absolute_error: 0.0823
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0082 - mean_absolute_error: 0.0697 - val_loss: 0.0099 - val_mean_absolute_error: 0.0822
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0081 - mean_absolute_error: 0.0694 - val_loss: 0.0098 - val_mean_absolute_error: 0.0818
# Epoch 23/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0080 - mean_absolute_error: 0.0691 - val_loss: 0.0098 - val_mean_absolute_error: 0.0814
# Epoch 24/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0079 - mean_absolute_error: 0.0688 - val_loss: 0.0097 - val_mean_absolute_error: 0.0810
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0079 - mean_absolute_error: 0.0685 - val_loss: 0.0096 - val_mean_absolute_error: 0.0807
# Epoch 26/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0078 - mean_absolute_error: 0.0682 - val_loss: 0.0096 - val_mean_absolute_error: 0.0804
# Epoch 27/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0077 - mean_absolute_error: 0.0678 - val_loss: 0.0095 - val_mean_absolute_error: 0.0801
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_absolute_error: 0.0675 - val_loss: 0.0094 - val_mean_absolute_error: 0.0798
# Epoch 29/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0076 - mean_absolute_error: 0.0671 - val_loss: 0.0093 - val_mean_absolute_error: 0.0796
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0075 - mean_absolute_error: 0.0669 - val_loss: 0.0094 - val_mean_absolute_error: 0.0796
# Epoch 31/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0074 - mean_absolute_error: 0.0665 - val_loss: 0.0092 - val_mean_absolute_error: 0.0790
# Epoch 32/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0073 - mean_absolute_error: 0.0661 - val_loss: 0.0091 - val_mean_absolute_error: 0.0786
# Epoch 33/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0072 - mean_absolute_error: 0.0657 - val_loss: 0.0091 - val_mean_absolute_error: 0.0785
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0072 - mean_absolute_error: 0.0654 - val_loss: 0.0089 - val_mean_absolute_error: 0.0777
# Epoch 35/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0071 - mean_absolute_error: 0.0650 - val_loss: 0.0089 - val_mean_absolute_error: 0.0776
# Epoch 36/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0070 - mean_absolute_error: 0.0646 - val_loss: 0.0088 - val_mean_absolute_error: 0.0773
# Epoch 37/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0069 - mean_absolute_error: 0.0642 - val_loss: 0.0087 - val_mean_absolute_error: 0.0767
# Epoch 38/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0068 - mean_absolute_error: 0.0638 - val_loss: 0.0086 - val_mean_absolute_error: 0.0763
# Epoch 39/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0634 - val_loss: 0.0086 - val_mean_absolute_error: 0.0760
# Epoch 40/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0066 - mean_absolute_error: 0.0629 - val_loss: 0.0085 - val_mean_absolute_error: 0.0755
# Epoch 41/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0065 - mean_absolute_error: 0.0625 - val_loss: 0.0083 - val_mean_absolute_error: 0.0747
# Epoch 42/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0064 - mean_absolute_error: 0.0620 - val_loss: 0.0083 - val_mean_absolute_error: 0.0748
# Epoch 43/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0064 - mean_absolute_error: 0.0618 - val_loss: 0.0083 - val_mean_absolute_error: 0.0747
# Epoch 44/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0062 - mean_absolute_error: 0.0610 - val_loss: 0.0080 - val_mean_absolute_error: 0.0733
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0061 - mean_absolute_error: 0.0605 - val_loss: 0.0079 - val_mean_absolute_error: 0.0732
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0060 - mean_absolute_error: 0.0598 - val_loss: 0.0078 - val_mean_absolute_error: 0.0730
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0058 - mean_absolute_error: 0.0592 - val_loss: 0.0077 - val_mean_absolute_error: 0.0725
# Epoch 48/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0586 - val_loss: 0.0076 - val_mean_absolute_error: 0.0721
# Epoch 49/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0055 - mean_absolute_error: 0.0575 - val_loss: 0.0072 - val_mean_absolute_error: 0.0706
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - mean_absolute_error: 0.0565 - val_loss: 0.0070 - val_mean_absolute_error: 0.0692

# %% [markdown]
# independent and dependent variables

# %%
# Define needed variables
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

# Plot training history
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# Prediction

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 2ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.7619460550584245
